# %%
sanket= ("Hello Python")
print (sanket)
# Out:
# Hello Python

# %%
name = "sanket"
age = 23
salary = 50000
print("I m:", name, "My age is:", age, "the salary is:", salary)
# Out:
# I m: sanket My age is: 23 the salary is: 50000

# %%
name = "sanket"
age = 23
salary = 500.567
old = False
a = None
print(type(name))
print(type(age))
print(type(salary))
print(type(old))
print(type(a))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'NoneType'>

# %%
#arithmetics operators
a = int (input("enter your value 1"))
b = int (input("enter your value 2"))
c = a+b
d = a-b
e = a/b
f = a*b
g = a%b # find remainder
h = a**b # powers of
print("addition:",c,
      "sub:", d,
      "Division:",e,
      "Multi:", f,
      "remainder:",g,
      "SKKKK:",h)
# Out:
# enter your value 1 5
# enter your value 2 2
# addition: 7 sub: 3 Division: 2.5 Multi: 10 remainder: 1 SKKKK: 25

# %%
 #relational operators
a= 50
b= 20
print(a==b)
print(a!=b)
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
# Out:
# False
# True
# True
# False
# True
# False

# %%
#Assignment Operator
num = 10
num  += 10 # here this is all operators:- =,+=,-=,*=,/=,%=,**=,//=

print("number is:",num)
# Out:
# number is: 20

# %%
#Logical Operators
#not operators
a= 50
b=20
print(not False)
print(not (a>b))

#And operators
val1 = True
val2 = True
print(val1 and val2)

#OR Operators
print (val1 or val2)
# Out:
# True
# False
# True
# True

# %%
#Type Conversion
a = int ("2")
b = 4.25
print (type(a))
print(a+b)
# Out:
# <class 'int'>
# 6.25

# %%
name = input ("Your name is")
age = int(input("your age is"))
salary = float (input("Your salary is"))
print ( name, age, salary)
# Out:
# Your name is Sanket
# your age is 23
# Your salary is 50000
# Sanket 23 50000.0

# %%
#write a program to input 2 numbers & print their sum
a = int(input ("enter first:"))
b = int(input ("enter second:"))
print("Sum =", a+b)
# Out:
# enter first: 20
# enter second: 30
# Sum = 50

# %%
#WAP to input side of a square nd print its area
a = float(input("enter first side"))
b = float(input("enter second side"))
print ("Area of sq is:", a*b)
# Out:
# enter first side 4
# enter second side 4
# Area of sq is: 16.0

# %%
#for next line...next line= \n & for tab= \t
str =  "I m sanket. \nmy age is 23"
print(str)
# Out:
# I m sanket.
# my age is 23

# %%
#For length
str1 = "SBUP University"
print(len(str1))

str2 = "Pune"
len2 = len(str2)
print(len2)

final_str = str1 + " " + str2 #spaces also calculated
print (final_str)
print(len(final_str))
# Out:
# 15
# 4
# SBUP University Pune
# 20

# %%
#indexing
str = "SBUP University"
print(str[7])
# Out:
# i

# %%
#Slicing
str = "SBUP university"
print(str[0:6])
print(str[7:]) #etc
print(str[-9:-5])
# Out:
# SBUP u
# iversity
# nive

# %%
#str.endswith()
str = "i m studing Python from SBUP"
print(str.endswith("SBUP"))
print(str.endswith("from"))
# Out:
# True
# False

# %%
#str.capitalize()
str = "i m studing Python from SBUP"
print(str.capitalize()) 

#first time yeh starting ka word capital krta hai but 2nd time nhi hota
# for fixed this we can

str = str.capitalize()
print(str)
# Out:
# I m studing python from sbup
# I m studing python from sbup

# %%
#str.replace()
str = "i m studing Python from SBUP"
print(str.replace("SBUP","AISSMS"))
# Out:
# i m studing Python from AISSMS

# %%
#str.find()
str = "i m studing Python from SBUP"
print(str.find("SBUP"))
# Out:
# 24

# %%
#str.count()
str = "i m studing Python from SBUP"
print(str.count("P"))
# Out:
# 2

# %%
l = float(input("enter length of rectangle"))
b = float (input("enter breath of rectangle"))
area = l*b
print("length:",l,
      "breath:",b,
      "Area:", area)
# Out:
# enter length of rectangle 20
# enter breath of rectangle 10
# length: 20.0 breath: 10.0 Area: 200.0
