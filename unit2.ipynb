# %%
#WAP to input users fiirst name & print its length
name = input("enter your name: ")
print("length of your name is", len(name))
# Out:
# enter your name:  sanket
# length of your name is 6

# %%
#WAp to find the occurrence of '$' in a string
str = "hi i m $ the $ symbol $89389"
print(str.count("$"))
# Out:
# 3

# %%
#Conditional statements
#if_elif_else 
age = 28 
if (age >= 18):
      print("can vote")
      print("can drive")
# Out:
# can vote
# can drive

# %%
light = "green"
if(light == "red"):
    print("stop")
elif(light == "green"):
    print("go")
elif(light == "yellow"):
    print("look")
print("end of code")
# Out:
# go
# end of code

# %%
 a = int ( input ( "Enter a number: " ) )
 b = int ( input ( "Enter another number: " ) )
 if a > b :
     print ( "First no is greater than the second no" )
     print ("in if Block") 
 else :
     print ( "Second no is greater than first no" )
     print ("in else Block")
     print ("not in if and not in else Block")
# Out:
# Enter a number:  20
# Enter another number:  10
# First no is greater than the second no
# in if Block

# %%
 i = 28
 if (i == 10): 
    print ("i is 10") 
 elif (i == 15): 
    print ("i is 15") 
 elif (i == 20): 
    print ("i is 20") 
 else: 
     print ("i is not present")
# Out:
# i is not present

# %%
 a = input("Enter a number: ")
 b = input("Enter another number: ")
 if a>b:
     print("First no is greater then Second no")
 elif a==b:
     print("Numbers are equal")
 else:
     print("Second no is greater than First no")
# Out:
# Enter a number:  10
# Enter another number:  10
# Numbers are equal

# %%
a = 14
rem = a % 2
if (rem == 0):
    print("Number is Even")
else:
    print("Number is Odd")
# Out:
# Number is Even

# %%
a= int(input("Enter first number:"))
b=int(input("Enter second number:"))
c=int(input("Enter third number:"))
if (a >= b and a>= c):
    print ("first is greater value")
elif (b>= c and b>= a):
    print ("second is greater value")
elif (c>= a and c>= b):
    print ("third is greater value")
else:
    print("end code")
# Out:
# Enter first number: 20
# Enter second number: 10
# Enter third number: 5
# first is greater value

# %%
a= int(input("Enter number:"))
if (a % 7 == 0):
    print("multiple of 7")
else:
    print ("not")
# Out:
# Enter number: 21
# multiple of 7
